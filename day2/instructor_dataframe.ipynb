# %% [markdown]
# # Pandas DataFrame

# %%
import pandas as pd
data = pd.read_csv('data/gapminder_gdp_europe.csv', index_col="country")

# %%
data.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                    2760.196931     3313.422188     3533.003910
# Austria                   12834.602400    16661.625600    19749.422300
# Belgium                   13149.041190    16672.143560    19117.974480
# Bosnia and Herzegovina     2172.352423     2860.169750     3528.481305
# Bulgaria                   5577.002800     6597.494398     7612.240438
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
data.tail()
# Out:
#                 gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Spain              3834.034742     4564.802410     5693.843879
# Sweden             8527.844662     9911.878226    12329.441920
# Switzerland       14734.232750    17909.489730    20431.092700
# Turkey             1969.100980     2218.754257     2322.869908
# United Kingdom     9979.508487    11283.177950    12477.177070
#
#                 gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Spain              7993.512294     10638.75131    13236.921170
# Sweden            15258.296970     17832.02464    18855.725210
# Switzerland       22966.144320     27195.11304    26982.290520
# Turkey             2826.356387      3450.69638     4269.122326
# United Kingdom    14142.850890     15895.11641    17428.748460
#
#                 gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# Spain             13926.169970    15764.983130    18603.064520
# ...

# %%
data.iloc[0,0]
# Out:
# 1601.056136

# %%
data.loc['Belgium', 'gdpPercap_1957']
# Out:
# 9714.960623

# %%
data.loc['Belgium']
# Out:
# gdpPercap_1952     8343.105127
# gdpPercap_1957     9714.960623
# gdpPercap_1962    10991.206760
# gdpPercap_1967    13149.041190
# gdpPercap_1972    16672.143560
# gdpPercap_1977    19117.974480
# gdpPercap_1982    20979.845890
# gdpPercap_1987    22525.563080
# gdpPercap_1992    25575.570690
# gdpPercap_1997    27561.196630
# gdpPercap_2002    30485.883750
# gdpPercap_2007    33692.605080
# Name: Belgium, dtype: float64

# %%
data.loc['Belgium',:]
# Out:
# gdpPercap_1952     8343.105127
# gdpPercap_1957     9714.960623
# gdpPercap_1962    10991.206760
# gdpPercap_1967    13149.041190
# gdpPercap_1972    16672.143560
# gdpPercap_1977    19117.974480
# gdpPercap_1982    20979.845890
# gdpPercap_1987    22525.563080
# gdpPercap_1992    25575.570690
# gdpPercap_1997    27561.196630
# gdpPercap_2002    30485.883750
# gdpPercap_2007    33692.605080
# Name: Belgium, dtype: float64

# %%
data.loc[['Belgium','Switzerland'],:]
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Belgium         8343.105127     9714.960623     10991.20676     13149.04119
# Switzerland    14734.232750    17909.489730     20431.09270     22966.14432
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Belgium         16672.14356     19117.97448     20979.84589     22525.56308
# Switzerland     27195.11304     26982.29052     28397.71512     30281.70459
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Belgium         25575.57069     27561.19663     30485.88375     33692.60508
# Switzerland     31871.53030     32135.32301     34480.95771     37506.41907

# %%
data.loc[['Belgium','Switzerland'],:].T.corr()
# Out:
# country       Belgium  Switzerland
# country
# Belgium      1.000000     0.976492
# Switzerland  0.976492     1.000000

# %%
data.loc[:,'gdpPercap_1987':'gdpPercap_2002'].head()
# Out:
#                         gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# country
# Albania                    3738.932735     2497.437901     3193.054604
# Austria                   23687.826070    27042.018680    29095.920660
# Belgium                   22525.563080    25575.570690    27561.196630
# Bosnia and Herzegovina     4314.114757     2546.781445     4766.355904
# Bulgaria                   8239.854824     6302.623438     5970.388760
#
#                         gdpPercap_2002
# country
# Albania                    4604.211737
# Austria                   32417.607690
# Belgium                   30485.883750
# Bosnia and Herzegovina     6018.975239
# Bulgaria                   7696.777725

# %%
data.loc[:,'gdpPercap_1987':'gdpPercap_2002'].mean()
# Out:
# gdpPercap_1987    17214.310727
# gdpPercap_1992    17061.568084
# gdpPercap_1997    19076.781802
# gdpPercap_2002    21711.732422
# dtype: float64

# %%
data.loc[:,'gdpPercap_1987':'gdpPercap_2002'].T.mean()
# Out:
# country
# Albania                    3508.409244
# Austria                   28060.843275
# Belgium                   26537.053538
# Bosnia and Herzegovina     4411.556836
# Bulgaria                   7052.411187
# Croatia                   10943.593070
# Czech Republic            16063.047270
# Denmark                   28373.440347
# Finland                   23429.179498
# France                    25396.513875
# Germany                   27242.293743
# Greece                    18730.994418
# Hungary                   12519.705222
# Iceland                   27822.974978
# Ireland                   22507.669647
# Italy                     23466.000577
# Montenegro                 7939.664209
# Netherlands               28603.290408
# Norway                    37868.443882
# Poland                     9745.763795
# Portugal                  16714.628705
# Romania                    7881.647709
# Serbia                    10086.585576
# Slovak Republic           11825.186081
# ...

# %%
data.iloc[:,0:3]
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
subset =data.loc[:,'gdpPercap_1987':'gdpPercap_2002']
print('where are the values large', subset>10000)
# Out:
# where are the values large                         gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
# Croatia                           True           False           False
# Czech Republic                    True            True            True
# Denmark                           True            True            True
# Finland                           True            True            True
# France                            True            True            True
# Germany                           True            True            True
# Greece                            True            True            True
# ...

# %%
subset>10000
# Out:
#                         gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
# Croatia                           True           False           False
# Czech Republic                    True            True            True
# Denmark                           True            True            True
# Finland                           True            True            True
# France                            True            True            True
# Germany                           True            True            True
# Greece                            True            True            True
# ...

# %%
mask = subset> 10000
mask.head()
# Out:
#                         gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
#
#                         gdpPercap_2002
# country
# Albania                          False
# Austria                           True
# Belgium                           True
# Bosnia and Herzegovina           False
# Bulgaria                         False

# %%
subset[mask]
# Out:
#                         gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# country
# Albania                            NaN             NaN             NaN
# Austria                    23687.82607     27042.01868     29095.92066
# Belgium                    22525.56308     25575.57069     27561.19663
# Bosnia and Herzegovina             NaN             NaN             NaN
# Bulgaria                           NaN             NaN             NaN
# Croatia                    13822.58394             NaN             NaN
# Czech Republic             16310.44340     14297.02122     16048.51424
# Denmark                    25116.17581     26406.73985     29804.34567
# Finland                    21141.01223     20647.16499     23723.95020
# France                     22066.44214     24703.79615     25889.78487
# Germany                    24639.18566     26505.30317     27788.88416
# Greece                     16120.52839     17541.49634     18747.69814
# ...

# %%
mask_higher = data.apply(lambda x: x>x.mean(),axis=0)
mask_higher.head()
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Albania                          False           False           False
# Austria                           True            True            True
# Belgium                           True            True            True
# Bosnia and Herzegovina           False           False           False
# Bulgaria                         False           False           False
#
#                         gdpPercap_1982  gdpPercap_1987  gdpPercap_1992  \
# country
# ...

# %%
data[mask_higher]
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                            NaN             NaN             NaN
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina             NaN             NaN             NaN
# Bulgaria                           NaN             NaN             NaN
# Croatia                            NaN             NaN             NaN
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                             NaN             NaN             NaN
# ...

# %%
help(data.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func, axis=0, broadcast=False, raw=False, reduce=None, args=(), **kwds) method of pandas.core.frame.DataFrame instance
#     Applies function along input axis of DataFrame.
#
#     Objects passed to functions are Series objects having index
#     either the DataFrame's index (axis=0) or the columns (axis=1).
#     Return type depends on whether passed function aggregates, or the
#     reduce argument if the DataFrame is empty.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column/row
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         * 0 or 'index': apply function to each column
#         * 1 or 'columns': apply function to each row
#     broadcast : boolean, default False
#         For aggregation functions, return object of same size with values
#         propagated
#     raw : boolean, default False
# ...

# %%
wealth_score = mask_higher.aggregate('sum',axis=1)/len(data.columns)
wealth_score.head()
# Out:
# country
# Albania                   0.0
# Austria                   1.0
# Belgium                   1.0
# Bosnia and Herzegovina    0.0
# Bulgaria                  0.0
# dtype: float64

# %%
data.groupby(wealth_score).sum().head()
# Out:
#           gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0.000000    36916.854200    46110.918793    56850.065437    71324.848786
# 0.333333    16790.046878    20942.456800    25744.935321    33567.667670
# 0.500000    11807.544405    14505.000150    18380.449470    21421.846200
# 1.000000   104317.277560   127332.008735   149989.154201   178000.350040
#
#           gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0.000000    88569.346898   104459.358438   113553.768507   119649.599409
# 0.333333    45277.839976    53860.456750    59679.634020    64436.912960
# 0.500000    25377.727380    29056.145370    31914.712050    35517.678220
# 1.000000   215162.343140   241143.412730   263388.781960   296825.131210
#
#           gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# 0.000000    92380.047256   103772.937598   118590.929863   149577.357928
# 0.333333    67918.093220    80876.051580   102086.795210   122803.729520
# ...

# %%
mask_higher.mean(axis=1).head()
# Out:
# country
# Albania                   0.0
# Austria                   1.0
# Belgium                   1.0
# Bosnia and Herzegovina    0.0
# Bulgaria                  0.0
# dtype: float64

# %%
help(mask_higher.aggregate)
# Out:
# Help on method aggregate in module pandas.core.frame:
#
# aggregate(func, axis=0, *args, **kwargs) method of pandas.core.frame.DataFrame instance
#     Aggregate using callable, string, dict, or list of string/callables
#
#     .. versionadded:: 0.20.0
#
#     Parameters
#     ----------
#     func : callable, string, dictionary, or list of string/callables
#         Function to use for aggregating the data. If a function, must either
#         work when passed a DataFrame or when passed to DataFrame.apply. For
#         a DataFrame, can pass a dict, if the keys are DataFrame column names.
#
#         Accepted Combinations are:
#
#         - string function name
#         - function
#         - list of functions
#         - dict of column names -> functions (or list of functions)
#
#     Notes
#     -----
#     Numpy functions mean/median/prod/sum/std/var are special cased so the
#     default behavior is applying the function along axis=0
# ...

# %%
# %load code/ex_dataframe

# %%
## DataFrames Excercise 1

# %% [markdown]
# ## DataFrames Excercise 1
#  Write an expression to find the Per Capita GDP of Serbia in 2007.

# %%
data.loc['Serbia','gdpPercap_2007']
# Out:
# 9786.534714

# %% [markdown]
# ## DataFrames Excercise 2: DataFrame slicing
# 1. Do the two statements below produce the same output?
# 1. Based on this, what rule governs what is included (or not) in numerical slices and named slices in Pandas?

# %%
print(data.iloc[0:2, 0:2])
print(data.loc['Albania':'Belgium', 'gdpPercap_1952':'gdpPercap_1962'])
# Out:
#          gdpPercap_1952  gdpPercap_1957
# country
# Albania     1601.056136     1942.284244
# Austria     6137.076492     8842.598030
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962
# country
# Albania     1601.056136     1942.284244     2312.888958
# Austria     6137.076492     8842.598030    10750.721110
# Belgium     8343.105127     9714.960623    10991.206760

# %%
## DataFrames Excercise 3
# Improve the following code with comments and better variable names

first = pd.read_csv('data/gapminder_all.csv', index_col='country')
first.head()
# Out:
#              continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria         Africa     2449.008185     3013.976023     2550.816880
# Angola          Africa     3520.610273     3827.940465     4269.276742
# Benin           Africa     1062.752200      959.601080      949.499064
# Botswana        Africa      851.241141      918.232535      983.653976
# Burkina Faso    Africa      543.255241      617.183465      722.512021
#
#               gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# country
# Algeria          3246.991771     4182.663766     4910.416756     5745.160213
# Angola           5522.776375     5473.288005     3008.647355     2756.953672
# Benin            1035.831411     1085.796879     1029.161251     1277.897616
# Botswana         1214.709294     2263.611114     3214.857818     4551.142150
# Burkina Faso      794.826560      854.735976      743.387037      807.198586
#
# ...

# %%
second = first[first['continent'] == 'Americas']
second
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
third = second.drop('Puerto Rico')
third
# Out:
#                     continent  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Argentina            Americas     5911.315053     6856.856212     7133.166023
# Bolivia              Americas     2677.326347     2127.686326     2180.972546
# Brazil               Americas     2108.944355     2487.365989     3336.585802
# Canada               Americas    11367.161120    12489.950060    13462.485550
# Chile                Americas     3939.978789     4315.622723     4519.094331
# Colombia             Americas     2144.115096     2323.805581     2492.351109
# Costa Rica           Americas     2627.009471     2990.010802     3460.937025
# Cuba                 Americas     5586.538780     6092.174359     5180.755910
# Dominican Republic   Americas     1397.717137     1544.402995     1662.137359
# Ecuador              Americas     3522.110717     3780.546651     4086.114078
# El Salvador          Americas     3048.302900     3421.523218     3776.803627
# ...

# %%
fourth = third.drop('continent', axis = 1)
fourth.head()
# Out:
#            gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Argentina     5911.315053     6856.856212     7133.166023     8052.953021
# Bolivia       2677.326347     2127.686326     2180.972546     2586.886053
# Brazil        2108.944355     2487.365989     3336.585802     3429.864357
# Canada       11367.161120    12489.950060    13462.485550    16076.588030
# Chile         3939.978789     4315.622723     4519.094331     5106.654313
#
#            gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Argentina     9443.038526    10079.026740     8997.897412     9139.671389
# Bolivia       2980.331339     3548.097832     3156.510452     2753.691490
# Brazil        4985.711467     6660.118654     7030.835878     7807.095818
# Canada       18970.570860    22090.883060    22898.792140    26626.515030
# Chile         5494.024437     4756.763836     5095.665738     5547.063754
#
# ...

# %%
fourth.to_csv('result.csv')

# bonus: is your current working directory the best place to save processed data?

# %%
check_result = pd.read_csv('result.csv')
check_result.head()
# Out:
#      country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# 0  Argentina     5911.315053     6856.856212     7133.166023     8052.953021
# 1    Bolivia     2677.326347     2127.686326     2180.972546     2586.886053
# 2     Brazil     2108.944355     2487.365989     3336.585802     3429.864357
# 3     Canada    11367.161120    12489.950060    13462.485550    16076.588030
# 4      Chile     3939.978789     4315.622723     4519.094331     5106.654313
#
#    gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# 0     9443.038526    10079.026740     8997.897412     9139.671389
# 1     2980.331339     3548.097832     3156.510452     2753.691490
# 2     4985.711467     6660.118654     7030.835878     7807.095818
# 3    18970.570860    22090.883060    22898.792140    26626.515030
# 4     5494.024437     4756.763836     5095.665738     5547.063754
#
#    gdpPercap_1992    ...        pop_1962    pop_1967     pop_1972  \
# ...

# %%
## DataFrames Excercise 4
# Add documentation to the following excerpt and make yourself some notes about
# what `idxmin` and `idxmax` and where you would use them
data = pandas.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
print(data.idxmin())
print(data.idxmax())

# %%
## DataFrames Excercise 5

#Generate the following stats as

# GDP per capita for all countries in 1982.
# GDP per capita for Denmark for all years.
# GDP per capita for all countries for years after 1985.
# GDP per capita for each country in 2007 as a multiple of GDP per capita for
#   that country in 1952.
